# %%
from platipy.imaging import ImageVisualiser
import SimpleITK as sitk

# %%
#pip install Platipy

# %%
# read in image using SimpleITK (included with platipy)
img = sitk.ReadImage(r"/home/tutkijat/Documents/repos/tmp-muscle-seg/HeadCTSegmentation/results_folder/05_15_08_15_48_MODEL_PREDICT/Image_54.nii.gz")

vis = ImageVisualiser(img, axis="z", cut=15, figure_size_in=6) #max cut 43
fig = vis.show()

# %%
img = sitk.ReadImage(r"/home/tutkijat/Documents/repos/tmp-muscle-seg/HeadCTSegmentation/results_folder/05_15_08_15_48_MODEL_PREDICT/Prediction_54.nii.gz")

vis = ImageVisualiser(img, axis="z", cut=15, figure_size_in=6)
fig = vis.show()
