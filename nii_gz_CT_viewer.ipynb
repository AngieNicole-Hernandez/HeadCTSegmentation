# %%
from platipy.imaging import ImageVisualiser
import SimpleITK as sitk
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\rtgcm\Documents\Nicole_documents\o-s_hs_repos\HeadCTSegmentation-master\nii_gz_MRI_viewer.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rtgcm/Documents/Nicole_documents/o-s_hs_repos/HeadCTSegmentation-master/nii_gz_MRI_viewer.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from platipy.imaging import ImageVisualiser
#       <a href='vscode-notebook-cell:/c%3A/Users/rtgcm/Documents/Nicole_documents/o-s_hs_repos/HeadCTSegmentation-master/nii_gz_MRI_viewer.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import SimpleITK as sitk
#
# ModuleNotFoundError: No module named 'platipy'

# %%
#pip install Platipy
# Out:
# ...
#                                               0.0/1.1 MB ? eta -:--:--
#      ---------------                          0.4/1.1 MB 13.2 MB/s eta 0:00:01
#      ------------------------------           0.8/1.1 MB 10.2 MB/s eta 0:00:01
#      ---------------------------------------  1.0/1.1 MB 11.0 MB/s eta 0:00:01
#      ---------------------------------------  1.1/1.1 MB 7.4 MB/s eta 0:00:01
#      ---------------------------------------  1.1/1.1 MB 7.4 MB/s eta 0:00:01
#      ---------------------------------------- 1.1/1.1 MB 5.2 MB/s eta 0:00:00
# ...
#                                               0.0/18.1 MB ? eta -:--:--
#      -                                        0.5/18.1 MB 9.6 MB/s eta 0:00:02
#      -                                        0.9/18.1 MB 11.4 MB/s eta 0:00:02
#      --                                       1.0/18.1 MB 11.0 MB/s eta 0:00:02
#      --                                       1.0/18.1 MB 11.0 MB/s eta 0:00:02
# ...

# %%
# read in image using SimpleITK (included with platipy)
img = sitk.ReadImage(r"C:\Users\rtgcm\Documents\Nicole_documents\o-s_hs_repos\HeadCTSegmentation-master\image_data_predict\1.nii.gz")

vis = ImageVisualiser(img, axis="z", cut=15, figure_size_in=6) #max cut 43
fig = vis.show()

# %%
img = sitk.ReadImage(r"C:\Users\rtgcm\Documents\Nicole_documents\o-s_hs_repos\HeadCTSegmentation-master\results_folder\07_25_15_22_47_MODEL_PREDICT\prediction_1.nii.gz")

vis = ImageVisualiser(img, axis="z", cut=15, figure_size_in=6)
fig = vis.show()
